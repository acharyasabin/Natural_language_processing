# %% [markdown]
# Text_classification
#
# SMSSpamCollection dataset from UCI datasets.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('smsspamcollection/SMSSpamCollection.tsv', sep='\t')
df.head()
# Out:
#   label                                            message
# 0   ham  I've been searching for the right words to tha...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  Nah I don't think he goes to usf, he lives aro...
# 3   ham  Even my brother is not like to speak with me. ...
# 4   ham                I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
len(df)
# Out:
# 4833

# %%
df.isnull(), df.isnull().sum()
# Out:
# (      label  message
#  0     False    False
#  1     False    False
#  2     False    False
#  3     False    False
#  4     False    False
#  ...     ...      ...
#  4828  False    False
#  4829  False    False
#  4830  False    False
#  4831  False    False
#  4832  False    False
#
#  [4833 rows x 2 columns],
#  label      0
#  message    0
#  dtype: int64)

# %%
df['label'].unique(), df['label'].value_counts()
# Out:
# (array(['ham', 'spam'], dtype=object),
#  ham     4196
#  spam     637
#  Name: label, dtype: int64)

# %%
df['label'].describe()
# Out:
# count     4833
# unique       2
# top        ham
# freq      4196
# Name: label, dtype: object

# %%
df[df['label'] == 'ham'],df[df['label'] == 'spam']
# Out:
# (     label                                            message
#  0      ham  I've been searching for the right words to tha...
#  2      ham  Nah I don't think he goes to usf, he lives aro...
#  3      ham  Even my brother is not like to speak with me. ...
#  4      ham                I HAVE A DATE ON SUNDAY WITH WILL!!
#  5      ham  As per your request 'Melle Melle (Oru Minnamin...
#  ...    ...                                                ...
#  4826   ham                                       Huh y lei...
#  4829   ham               Will ü b going to esplanade fr home?
#  4830   ham  Pity, * was in mood for that. So...any other s...
#  4831   ham  The guy did some bitching but I acted like i'd...
#  4832   ham                         Rofl. Its true to its name
#
#  [4196 rows x 2 columns],
#       label                                            message
#  1     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# ...

# %%
#splitting dataset

# %%
from sklearn.model_selection import  train_test_split

X = df['message']
Y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
X_train.shape,X_test.shape
# Out:
# ((3383,), (1450,))

# %%
#Sklearn CountVectorizer for text preprocessing, tokenizing and filter stopwords and build feature vectors.

from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()

X_train_counts = count_vect.fit_transform(X_train)
X_train_counts.shape
# Out:
# (3383, 7418)

# %%
#transform counts to frequencies with tf-idf
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()

X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (3383, 7418)

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC()
clf.fit(X_train_tfidf,y_train)
# Out:
# LinearSVC()

# %% [markdown]
# # Fitting using  pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer


model = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', LinearSVC()),
])

# Feed the training data through the pipeline
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
#testing the classifier
predictions = model.predict(X_test)
from sklearn import metrics
metrics.confusion_matrix(y_test,predictions)
# Out:
# array([[1247,    7],
#        [  17,  179]])

# %%
print(metrics.classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.99      0.99      0.99      1254
#         spam       0.96      0.91      0.94       196
#
#     accuracy                           0.98      1450
#    macro avg       0.97      0.95      0.96      1450
# weighted avg       0.98      0.98      0.98      1450

# %%
print(metrics.accuracy_score(y_test,predictions))
# Out:
# 0.983448275862069
