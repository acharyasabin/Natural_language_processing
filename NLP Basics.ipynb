# %% [markdown]
# **Beginning with Spacy**
#
# Statistical Models
#     These models enable to perform several NLP related tasks, such as part-of-speech tagging, named entity recognition, and dependency parsing.
#
# en_core_web_sm: English multi-task CNN trained on OntoNotes.
#
# Part-of-speech (POS) tagger
# Named entity recognizer (NER)
# Syntactic dependency parser
#
# Processing Pipeline
#
# text-- tokenizer-tagger-parser-ner...--doc
#
# --> pass text to NLP object

# %%
#nlp object
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
document = """Hello, i'm Sabin Acharya. I am a computer vision engineer. I wanted to learn NLP. \
So, I started my NLP journey from today dated:june 4th,2020 \
during the lockdown here in Nepal."""

# %%
doc = nlp(document)

# %% [markdown]
# Tokenization
# hierarchy: Corpus > document > sentence > word > sub-word > character > subcharacter > stroke
#
# Normally, uses whitespaces for tokenization while for some languages with no whitespaces:-
#
# Segment text into morphemes before tokenization.
#
# byte-pair-encoding (BPE) to create sub-word units.(Google's bert)

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Hello INTJ intj
# , PUNCT punct
# i PRON nsubj
# 'm AUX ROOT
# Sabin PROPN compound
# Acharya PROPN attr
# . PUNCT punct
# I PRON nsubj
# am AUX ROOT
# a DET det
# computer NOUN compound
# vision NOUN compound
# engineer NOUN attr
# . PUNCT punct
# I PRON nsubj
# wanted VERB ROOT
# to PART aux
# learn VERB xcomp
# NLP PROPN dobj
# . PUNCT punct
# So ADV advmod
# , PUNCT punct
# I PRON nsubj
# started VERB ROOT
# my DET poss
# NLP PROPN compound
# journey NOUN dobj
# from ADP prep
# today NOUN pobj
# dated VERB pcomp
# : PUNCT punct
# june PROPN compound
# 4th,2020 NUM npadvmod
# during ADP ROOT
# the DET det
# lockdown NOUN pobj
# here ADV advmod
# in ADP prep
# Nepal PROPN pobj
# . PUNCT punct

# %%
print(doc)
# Out:
# Hello, i'm Sabin Acharya. I am a computer vision engineer. I wanted to learn NLP. So, I started my NLP journey from today dated:june 4th,2020 during the lockdown here in Nepal.

# %% [markdown]
# stop words:-
# common words not used for word frequency, topic modeling, count vectorizer (to reduce features for, say, bag-of-word text classifier).

# %%
spacy_stop_words = spacy.lang.en.stop_words.STOP_WORDS
len(spacy_stop_words)
# Out:
# 326

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'name', 'throughout', 'however', 'and', 'put', 'since', 'next', 'various', 'yourself', 'few', '’ve', 'nor', '‘s', 'a', 'be', 'otherwise', 'another', 'how', 'our', 'thru', "'s", 'again', 'ever', 'first', "'d", 'whereby', 'more', 'up', "n't", 'bottom', 'them', 'as', 'full', 'must', 'sometimes', 'within', 'yet', 'for', 'yourselves', 'hundred', 'whither', 'against', 'empty', 'sixty', 'even', 'whether', 'therefore', 'elsewhere', 'no', 'hereafter', 'many', 'may', 'three', 'keep', 'towards', 'thus', 'ours', 'everyone', 'four', 'once', 'unless', 'if', 'eleven', 'forty', 'hence', 'here', 'its', 'except', 'everywhere', 'beforehand', 'just', 'themselves', 'cannot', 'someone', 'had', '‘ve', 'latterly', 'ca', 'fifty', 'an', 'of', 'where', 'did', 'were', 'whatever', 'nothing', 'say', 'am', 'being', 'using', 'why', 'only', '’ll', 'becomes', 'give', 'thereupon', 'whose', "'m", 'each', 'whole', 'some', 'also', 'something', 'somewhere', 'due', 'is', '’d', 'already', 'down', 'seem', 'thereafter', 'myself', 'amongst', 'because', 'rather', 'mine', 'beside', 'hereby', 'anyhow', 'whereupon', 'go', 'we', 'your', 'to', 'back', 'with', '‘ll', 'every', 'less', 'meanwhile', 'who', 'there', '‘re', 'without', 'along', 'anything', 'used', 'any', 'get', 'please', 'was', 'off', 'her', 'least', 'nobody', 'six', 're', '‘m', 'behind', 'nine', 'been', 'these', 'me', 'between', 'whom', 'whoever', 'during', 'him', 'own', 'front', 'n’t', 'although', 'several', 'take', 'moreover', 'on', 'so', 'would', 'became', 'such', 'until', 'through', 'under', 'while', 'doing', 'always', 'the', 'then', 'therein', 'you', 'are', 'his', 'neither', 'well', '’m', 'about', 'does', 'somehow', 'thereby', 'upon', 'seeming', '‘d', 'seemed', 'enough', 'further', 'nevertheless', 'than', 'toward', 'after', 'anyone', 'now', 'all', 'besides', 'do', 'fifteen', 'still', 'below', 'eight', 'latter', 'formerly', 'none', 'anyway', 'amount', 'i', 'never', 'everything', 'very', 'other', 'two', 'hers', 'what', 'make', 'show', 'though', 'twelve', 'which', 'my', 'side', 'in', 'former', 'ten', 'third', 'thence', 'see', 'should', 'quite', 'onto', 'else', 'into', 'top', 'have', 'wherein', 'out', 'done', 'same', 'serious', '’s', 'has', 'seems', 'beyond', 'not', 'whence', 'really', 'both', 'at', 'sometime', 'when', 'alone', 'itself', "'ll", 'become', 'it', 'noone', 'often', 'per', 'n‘t', 'made', 'nowhere', 'five', 'or', 'across', 'himself', 'those', 'herself', 'perhaps', 'mostly', 'this', 'from', 'most', 'hereupon', 'yours', 'much', 'ourselves', 'twenty', 'could', 'will', "'ve", 'together', 'part', 'their', 'last', 'she', 'before', 'move', 'that', 'herein', 'others', 'might', 'wherever', 'above', '’re', 'becoming', 'indeed', 'one', 'namely', 'us', 'via', 'by', 'can', 'he', 'but', 'regarding', 'over', 'they', 'whenever', 'among', 'whereas', 'too', 'afterwards', 'anywhere', 'either', "'re", 'call', 'whereafter', 'almost', 'around'}

# %%
nlp.vocab['myself'].is_stop#to check a stopword
# Out:
# True

# %%
nlp.Defaults.stop_words.add('btw')#to add a stopword

nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.Defaults.stop_words.remove('btw')#to add a stopword

nlp.vocab['btw'].is_stop = False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %% [markdown]
# Lemmatization:-reducing inflections or variant forms to base form
#
# is,am,are-- be
#
# car,cars,car's -- car
#
# Depends on part-of-speech (POS) tagging
#
# #text normalization
#
# not much used for deep learning tasks.

# %%
for token in doc:
    print(token.text, "\t\t",token.lemma_)
# Out:
# Hello 		 hello
# , 		 ,
# i 		 -PRON-
# 'm 		 be
# Sabin 		 Sabin
# Acharya 		 Acharya
# . 		 .
# I 		 -PRON-
# am 		 be
# a 		 a
# computer 		 computer
# vision 		 vision
# engineer 		 engineer
# . 		 .
# I 		 -PRON-
# wanted 		 want
# to 		 to
# learn 		 learn
# NLP 		 NLP
# . 		 .
# So 		 so
# , 		 ,
# I 		 -PRON-
# started 		 start
# my 		 -PRON-
# NLP 		 NLP
# journey 		 journey
# from 		 from
# today 		 today
# dated 		 date
# : 		 :
# june 		 june
# 4th,2020 		 4th,2020
# during 		 during
# the 		 the
# lockdown 		 lockdown
# here 		 here
# in 		 in
# Nepal 		 Nepal
# . 		 .

# %% [markdown]
# Sentence segmentation:-

# %%
for sentence in doc.sents:
    print(sentence)
# Out:
# Hello, i'm Sabin Acharya.
# I am a computer vision engineer.
# I wanted to learn NLP.
# So, I started my NLP journey from today dated:june 4th,2020
# during the lockdown here in Nepal.

# %% [markdown]
# NER:
#
# PERSON People, including fictional.
#
# FAC Buildings, airports, highways, bridges, etc.
#
# ORG Companies, agencies, institutions, etc.
#
# GPE Countries, cities, states.
#
# PRODUCT Objects, vehicles, foods, etc. (Not services.)
#
# EVENT Named hurricanes, battles, wars, sports events, etc.
#
# DATE Absolute or relative dates or periods.
#
# TIME Times smaller than a day.
#
# MONEY Monetary values, including unit.
#
# QUANTITY Measurements, as of weight or distance.
#
# ORDINAL “first”, “second”, etc.
#
# CARDINAL Numerals that do not fall under another type.

# %%
for token in doc.ents:
    print(token.text,token.label_)
# Out:
# Sabin Acharya PERSON
# NLP ORG
# NLP ORG
# today DATE
# june 4th,2020 DATE
# Nepal GPE

# %%
spacy.displacy.render(doc,style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Hello, i'm
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sabin Acharya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . I am a computer vision engineer. I wanted to learn
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . So, I started my
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  journey from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  dated:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     june 4th,2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  during the lockdown here in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nepal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %% [markdown]
# Syntactic dependency parser:-
#
# extract the dependency parse of a sentence to represent it's grammatical structure.
#
# represented as directed graph and can be used as features in graph neural network and tree-recursive NN.

# %%
for token in doc:
    print(token.text,"\t\t",token.dep_,"\t\t",token.head.text)
# Out:
# Hello 		 intj 		 'm
# , 		 punct 		 'm
# i 		 nsubj 		 'm
# 'm 		 ROOT 		 'm
# Sabin 		 compound 		 Acharya
# Acharya 		 attr 		 'm
# . 		 punct 		 'm
# I 		 nsubj 		 am
# am 		 ROOT 		 am
# a 		 det 		 engineer
# computer 		 compound 		 engineer
# vision 		 compound 		 engineer
# engineer 		 attr 		 am
# . 		 punct 		 am
# I 		 nsubj 		 wanted
# wanted 		 ROOT 		 wanted
# to 		 aux 		 learn
# learn 		 xcomp 		 wanted
# NLP 		 dobj 		 learn
# . 		 punct 		 wanted
# So 		 advmod 		 started
# , 		 punct 		 started
# I 		 nsubj 		 started
# started 		 ROOT 		 started
# my 		 poss 		 journey
# NLP 		 compound 		 journey
# journey 		 dobj 		 started
# from 		 prep 		 started
# today 		 pobj 		 from
# dated 		 pcomp 		 from
# : 		 punct 		 started
# june 		 compound 		 4th,2020
# 4th,2020 		 npadvmod 		 started
# during 		 ROOT 		 during
# the 		 det 		 lockdown
# lockdown 		 pobj 		 during
# here 		 advmod 		 lockdown
# in 		 prep 		 here
# Nepal 		 pobj 		 in
# . 		 punct 		 during

# %%
sentence_spans = list(doc.sents)
spacy.displacy.render(sentence_spans, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4f61e41d31ce4cfdb41165046ef4b5dd-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">'m</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Sabin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Acharya.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f61e41d31ce4cfdb41165046ef4b5dd-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f61e41d31ce4cfdb41165046ef4b5dd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f61e41d31ce4cfdb41165046ef4b5dd-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f61e41d31ce4cfdb41165046ef4b5dd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f61e41d31ce4cfdb41165046ef4b5dd-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f61e41d31ce4cfdb41165046ef4b5dd-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f61e41d31ce4cfdb41165046ef4b5dd-0-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f61e41d31ce4cfdb41165046ef4b5dd-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4f61e41d31ce4cfdb41165046ef4b5dd-1" class="displacy" width="1100" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">computer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">vision</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">engineer.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f61e41d31ce4cfdb41165046ef4b5dd-1-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f61e41d31ce4cfdb41165046ef4b5dd-1-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f61e41d31ce4cfdb41165046ef4b5dd-1-1" stroke-width="2px" d="M420,352.0 C420,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f61e41d31ce4cfdb41165046ef4b5dd-1-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f61e41d31ce4cfdb41165046ef4b5dd-1-2" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f61e41d31ce4cfdb41165046ef4b5dd-1-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f61e41d31ce4cfdb41165046ef4b5dd-1-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f61e41d31ce4cfdb41165046ef4b5dd-1-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="disp

# %%
print(doc.vocab)
# Out:
# <spacy.vocab.Vocab object at 0x7f5ee97d3d48>

# %%
print(len(doc),len(doc.vocab))
# Out:
# 40 513

# %% [markdown]
# nounchunks:-Noun chunks are "base noun phrases" – flat phrases that have a noun as their head

# %%
for chunk in doc.noun_chunks:
    print(chunk.text)
# Out:
# i
# Sabin Acharya
# I
# a computer vision engineer
# I
# NLP
# I
# my NLP journey
# today
# the lockdown
# Nepal

# %% [markdown]
# doc.sents, doc.ents, doc.noun_chunks, doc.vocab

# %% [markdown]
# NO stemming in spacy

# %%
import nltk
from nltk.stem.porter import *
#stemming tools is porter's algorithm

# %%
p_stemmer = PorterStemmer()

# %%
words = ['run','runner','running','ran','runs','sing','nicely','fairly']

# %%
for word in words:
    print(word+' --> '+p_stemmer.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# sing --> sing
# nicely --> nice
# fairly --> fairli

# %%
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer 
s_stemmer = SnowballStemmer(language='english')

# %%
for word in words:
    print(word+' --> '+p_stemmer.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# sing --> sing
# nicely --> nice
# fairly --> fairli

# %% [markdown]
# # Rule based matching
# find words and phrases in the text using user-defined rules.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
doc = nlp("""The page layout of a document is how information is graphically arranged in the space of the document, e.g., on a page. If the appearance of the document is of concern, the page layout is generally the responsibility of a graphic designer. Typography concerns the design of letter and symbol forms and their physical arrangement in the document (see typesetting). Information design concerns the effective communication of information, especially in industrial-document and public signs. Simple textual-documents may not require visual design and may be drafted only by an author, clerk, or transcriber. Forms may require a visual design for their initial fields, but not to complete the forms.""")

# %%
pattern = [{'LOWER': 'document'}]

# %%
matcher.add('matchername1', None, pattern)

# %%
found_matches = matcher(doc)
print(found_matches)
# Out:
# [(8469217569700685470, 5, 6), (8469217569700685470, 17, 18), (8469217569700685470, 30, 31), (8469217569700685470, 62, 63), (8469217569700685470, 81, 82)]

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]  # get string representation
    span = doc[start:end]                    # get the matched span
    print(match_id, string_id, start, end, span.text)
# Out:
# 8469217569700685470 matchername1 5 6 document
# 8469217569700685470 matchername1 17 18 document
# 8469217569700685470 matchername1 30 31 document
# 8469217569700685470 matchername1 62 63 document
# 8469217569700685470 matchername1 81 82 document

# %%
matcher.remove('matchername1')

# %%
pattern1 = [{'IS_PUNCT': True},{'LOWER': 'documents'}]

# %%
matcher.add('matchername2', None, pattern1)

# %%
found_matches = matcher(doc)
print(found_matches)
# Out:
# [(13298170584691041502, 88, 90)]

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]  # get string representation
    span = doc[start:end]                    # get the matched span
    print(match_id, string_id, start, end, span.text)
# Out:
# 13298170584691041502 matchername2 88 90 -documents

# %%
matcher.remove('matchername2')

# %% [markdown]
# # PhraseMatcher

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab)

# %%
doc = nlp("""The page layout of a document is how information is graphically arranged in the space of the document, e.g., on a page. If the appearance of the document is of concern, the page layout is generally the responsibility of a graphic designer. Typography concerns the design of letter and symbol forms and their physical arrangement in the document (see typesetting). Information design concerns the effective communication of information, especially in industrial-document and public signs. Simple textual-documents may not require visual design and may be drafted only by an author, clerk, or transcriber. Forms may require a visual design for their initial fields, but not to complete the forms.""")

# %%
phrase_list = ['document','documents']

# %%
phrase_patterns = [nlp(text) for text in phrase_list]

# %%
matcher.add('matcher1', None, *phrase_patterns)

matches = matcher(doc)

# %%
print(len(matches))
# Out:
# 6

# %%
print(matches)
# Out:
# [(10800829559984205610, 5, 6), (10800829559984205610, 17, 18), (10800829559984205610, 30, 31), (10800829559984205610, 62, 63), (10800829559984205610, 81, 82), (10800829559984205610, 89, 90)]

# %%
for match_id,start,end in matches:
    print(doc[start:end])
# Out:
# document
# document
# document
# document
# document
# documents
